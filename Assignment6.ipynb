# %% [markdown]
# <a href="https://colab.research.google.com/github/awkywoo/First-repo/blob/master/Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns
import statsmodels.formula.api as smf
import torch

# %% [markdown]
# Download data

# %%
! if [ ! -e data.txt ] ;\
  then wget https://raw.githubusercontent.com/ds4ph-bme/homework-6-awkywoo/master/data.txt?token=AOK35SOKD4V4XPJQR3BMGEK6R54Q4; fi;
# Out:
# --2020-04-02 20:12:37--  https://raw.githubusercontent.com/ds4ph-bme/homework-6-awkywoo/master/data.txt?token=AOK35SOKD4V4XPJQR3BMGEK6R54Q4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 734401 (717K) [text/plain]
# Saving to: ‘data.txt?token=AOK35SOKD4V4XPJQR3BMGEK6R54Q4.5’
#
# data.txt?token=AOK3 100%[===================>] 717.19K  --.-KB/s    in 0.06s
#
# 2020-04-02 20:12:37 (11.3 MB/s) - ‘data.txt?token=AOK35SOKD4V4XPJQR3BMGEK6R54Q4.5’ saved [734401/734401]

# %%
df = pd.read_table("data.txt?token=AOK35SOKD4V4XPJQR3BMGEK6R54Q4.5")

# %% [markdown]
# Plot regression scatterplot

# %%
pred = df['rdi4p'].apply(np.log) +1
sns.scatterplot(df['bmi_s1'], pred)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 62

# %% [markdown]
# Fitting the Data

# %%
fit = smf.ols('pred ~ bmi_s1', data = df).fit()
yhat = fit.predict(df['bmi_s1'])
sns.scatterplot(yhat, pred)
plt.plot([-1, 3], [-1, 3], linewidth=1)
